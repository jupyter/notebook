# %%
```python
(
    (
        r'^(DP.*-)[\dX]*(.*)$',
        r'\1\2',
    ), (
        r'-$',
        '',
    )
)
```
# Out:
#   File "<ipython-input-1-7caa3caa641b>", line 1
#     ```python
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ```python
# (
#     (
#         r'^(DP.*-)[\dX]*(.*)$',
#         r'\1\2',
#     ), (
#         r'-$',
#         '',
#     )
# )
# ```

# %% [markdown]
# ```python
# (
#     (
#         r'^(DP.*-)[\dX]*(.*)$',
#         r'\1\2',
#     ),
#     (
#         r'-$',
#         '',
#     )
# )
# ```
